# %% [markdown]
# # Data Quality food_access_research_atlas

# %%
import pandas as pd

# %%
#reading in food access data domain 
food_access_2015 = pd.read_csv("food_access_research_atlas_2015.csv")
food_access_2015.head()
# Out:
#    CensusTract    State   County  Urban  POP2010  OHU2010  GroupQuartersFlag  \
# 0   1001020100  Alabama  Autauga      1     1912      693                  0
# 1   1001020200  Alabama  Autauga      1     2170      743                  0
# 2   1001020300  Alabama  Autauga      1     3373     1256                  0
# 3   1001020400  Alabama  Autauga      1     4386     1722                  0
# 4   1001020500  Alabama  Autauga      1    10766     4082                  0
#
#    NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  TractSeniors  TractWhite  \
# 0         0  0.000000                  0  ...           221        1622
# 1       181  0.083410                  0  ...           214         888
# 2         0  0.000000                  0  ...           439        2576
# 3         0  0.000000                  0  ...           904        4086
# 4       181  0.016812                  0  ...          1126        8666
#
# ...

# %%
#Keep just the state of utah data
utah_mask = food_access_2015["State"]  == 'Utah'
food_access_2015 = food_access_2015.loc[utah_mask]
food_access_2015
# Out:
#        CensusTract State     County  Urban  POP2010  OHU2010  \
# 66726  49001100100  Utah     Beaver      0     3818     1338
# 66727  49001100200  Utah     Beaver      0     2811      927
# 66728  49003960100  Utah  Box Elder      0     3152      978
# 66729  49003960200  Utah  Box Elder      0     6901     2186
# 66730  49003960300  Utah  Box Elder      1     8186     2558
# ...            ...   ...        ...    ...      ...      ...
# 67309  49057210900  Utah      Weber      1     6316     2268
# 67310  49057211000  Utah      Weber      1     3073     1089
# 67311  49057211100  Utah      Weber      1     5785     2093
# 67312  49057211201  Utah      Weber      1     4452     1604
# 67313  49057211202  Utah      Weber      1     6531     2560
#
#        GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# 66726                  0        14  0.003667                  0  ...
# 66727                  0        10  0.003557                  0  ...
# ...

# %%
food_access_2015.to_csv('food_access_2015.csv', index=False)

# %%
#keeping the columns I want
#Field	LongName
#CensusTract	Census tract
#State	State
#County	County
#Urban	Urban tract
#POP2010	Population, tract total
#PovertyRate	Tract poverty rate
#MedianFamilyIncome	Tract median family income
#LA1and10	Low access tract at 1 mile for urban areas and 10 miles for rural areas
#LAhalfand10	Low access tract at 1/2 mile for urban areas and 10 miles for rural areas
#LA1and20	Low access tract at 1 mile for urban areas and 20 miles for rural areas
#LATracts_half	Low access tract at 1/2 mile
#LATracts1	Low access tract at 1 mile
#LATracts10	Low access tract at 10 miles
#LATracts20	Low access tract at 20 miles
#TractWhite	Tract White population, number
#TractBlack	Tract Black or African American population, number
#TractAsian	Tract Asian population, number
#TractNHOPI	Tract Native Hawaiian and Other Pacific Islander population, number
#TractAIAN	Tract American Indian and Alaska Native population, number
#TractOMultir	Tract Other/Multiple race population, number
#TractHispanic	Tract Hispanic or Latino population, number

food_access_2015 = food_access_2015[['CensusTract', 'State', 'County', 'Urban', 'POP2010', 'PovertyRate',
                                'MedianFamilyIncome', 'LA1and10', 'LAhalfand10', 'LA1and20', 
                                'LATracts_half', 'LATracts1', 'LATracts10', 'LATracts20',
                                'TractWhite', 'TractBlack', 'TractAsian', 
                                'TractNHOPI', 'TractAIAN', 'TractOMultir', 'TractHispanic']]
food_access_2015.head()
# Out:
#        CensusTract State     County  Urban  POP2010  PovertyRate  \
# 66726  49001100100  Utah     Beaver      0     3818         15.1
# 66727  49001100200  Utah     Beaver      0     2811         10.5
# 66728  49003960100  Utah  Box Elder      0     3152         13.7
# 66729  49003960200  Utah  Box Elder      0     6901          9.2
# 66730  49003960300  Utah  Box Elder      1     8186         14.7
#
#        MedianFamilyIncome  LA1and10  LAhalfand10  LA1and20  ...  LATracts1  \
# 66726               56250         0            0         0  ...          0
# 66727               62972         1            1         0  ...          0
# 66728               62798         1            1         1  ...          0
# 66729               63638         0            0         0  ...          0
# 66730               56216         1            1         1  ...          1
#
#        LATracts10  LATracts20  TractWhite  TractBlack  TractAsian  TractNHOPI  \
# ...

# %% [markdown]
# # Attribute domain constraints

# %% [markdown]
# Basic aggregate statistics for the food_access_2015 data domain

# %% [markdown]
# The descriptive statistics seem reasonable. The Low access columns and urban all have a min of 0 and Max of 1 as expected since they are binary results. All other columns seem reasonable.

# %%
food_access_2015.describe()
# Out:
#         CensusTract       Urban       POP2010  PovertyRate  \
# count  5.880000e+02  588.000000    588.000000   588.000000
# mean   4.903629e+10    0.846939   4700.484694    13.472619
# std    1.535444e+07    0.360353   2073.815323    11.281999
# min    4.900110e+10    0.000000      0.000000     0.000000
# 25%    4.903510e+10    1.000000   3438.500000     5.900000
# 50%    4.903511e+10    1.000000   4442.000000    10.150000
# 75%    4.904900e+10    1.000000   5785.750000    17.700000
# max    4.905721e+10    1.000000  21591.000000    85.500000
#
#        MedianFamilyIncome    LA1and10  LAhalfand10    LA1and20  LATracts_half  \
# count          588.000000  588.000000   588.000000  588.000000     588.000000
# mean         69030.653061    0.447279     0.828231    0.423469       0.778912
# std          24620.559447    0.497636     0.377500    0.494529       0.415333
# min              0.000000    0.000000     0.000000    0.000000       0.000000
# ...

# %%
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# This next line tells jupyter to render the images inline
# %matplotlib inline

# %% [markdown]
# The value counts for urban show that there are more urban census tracts than rural in the state of utah. LAhalfand10 is the varaible for low access tract at 1/2 mile for urban areas and 10 miles for rural areas. There are more 1's I assume mean yes than 0's which I assume mean no. There are 585 census tracts. Each row in the dataset represents a unique census tract. Salt Lake city county has the most census tracts with 211.

# %%
food_access_2015["Urban"].value_counts()
# Out:
# Urban
# 1    498
# 0     90
# Name: count, dtype: int64

# %%
food_access_2015["LAhalfand10"].value_counts()
# Out:
# LAhalfand10
# 1    487
# 0    101
# Name: count, dtype: int64

# %%
food_access_2015.groupby(['County']).describe()
#2015 data has 3 additional census tracts one additional in salt lake county, utah county, and tooele county
# Out:
#            CensusTract                                             \
#                  count          mean            std           min
# County
# Beaver             2.0  4.900110e+10      70.710678  4.900110e+10
# Box Elder         11.0  4.900396e+10     240.757970  4.900396e+10
# Cache             26.0  4.900504e+10  192064.627410  4.900500e+10
# Carbon             5.0  4.900700e+10     207.364414  4.900700e+10
# Daggett            1.0  4.900996e+10            NaN  4.900996e+10
# Davis             54.0  4.901113e+10     568.639313  4.901113e+10
# Duchesne           3.0  4.901394e+10     152.752523  4.901394e+10
# Emery              3.0  4.901598e+10     152.752523  4.901598e+10
# Garfield           2.0  4.901700e+10      70.710678  4.901700e+10
# Grand              2.0  4.901900e+10      70.710678  4.901900e+10
# Iron               8.0  4.902111e+10     226.882246  4.902111e+10
# Juab               2.0  4.902301e+10      70.710678  4.902301e+10
# ...

# %%
food_access_2015['CensusTract'].value_counts()
# Out:
# CensusTract
# 49001100100    1
# 49049000707    1
# 49049000203    1
# 49049000204    1
# 49049000205    1
#               ..
# 49035111304    1
# 49035111305    1
# 49035111306    1
# 49035111400    1
# 49057211202    1
# Name: count, Length: 588, dtype: int64

# %%
food_access_2015["County"].value_counts()
# Out:
# County
# Salt Lake     212
# Utah          128
# Davis          54
# Weber          50
# Cache          26
# Washington     21
# Summit         13
# Tooele         11
# Box Elder      11
# Iron            8
# Uintah          6
# Carbon          5
# Sanpete         5
# Sevier          5
# Wasatch         4
# San Juan        4
# Duchesne        3
# Emery           3
# Millard         3
# Beaver          2
# Kane            2
# Juab            2
# Grand           2
# Garfield        2
# Morgan          2
# Rich            1
# Piute           1
# Daggett         1
# Wayne           1
# Name: count, dtype: int64

# %% [markdown]
# Optionality was described as number of missing values in the paper. There are no missing values.

# %%
#checking for null values
food_access_2015.isnull().sum()
# Out:
# CensusTract           0
# State                 0
# County                0
# Urban                 0
# POP2010               0
# PovertyRate           0
# MedianFamilyIncome    0
# LA1and10              0
# LAhalfand10           0
# LA1and20              0
# LATracts_half         0
# LATracts1             0
# LATracts10            0
# LATracts20            0
# TractWhite            0
# TractBlack            0
# TractAsian            0
# TractNHOPI            0
# TractAIAN             0
# TractOMultir          0
# TractHispanic         0
# dtype: int64

# %% [markdown]
# # Relational integrity rules

# %% [markdown]
# The paper refers to checking for identity. In this data set that means making sure the CensusTract are unique. Using food_access_2015["CensusTract"].describe() shows that there are 588 rows in the table and 588 unique census tracts.

# %%
food_access_2015["CensusTract"].describe()
# Out:
# count    5.880000e+02
# mean     4.903629e+10
# std      1.535444e+07
# min      4.900110e+10
# 25%      4.903510e+10
# 50%      4.903511e+10
# 75%      4.904900e+10
# max      4.905721e+10
# Name: CensusTract, dtype: float64

# %% [markdown]
# The paper refers to checking for reference. Will need to check that the census tract can be used to join the individual datasets together.

# %% [markdown]
# # Historical data rules

# %% [markdown]
# Historical data rules according to the paper are rules that look at "time-varying data". Data sources: In the 2017 report, a directory of supermarkets, supercenters, and large grocery
# stores within the United States, including Alaska and Hawaii, was derived from merging the
# 2015 STARS directory of stores authorized to accept Supplemental Nutrition Assistance
# Program (SNAP) benefits and the 2015 Trade Dimensions TDLinx directory of stores. According to the documentation included with the data download.

# %% [markdown]
# # State dependent objects rules

# %% [markdown]
# The values for urban and for the low access columns can only be 0 or 1 not both or a value in between. Looking at the values counts in the attribute doman constraint section shows that this is the the case. The value counts show that 0 and 1 are the only values in the column and the totals add up to 588 as expected.

# %% [markdown]
# # Attribute dependency rules

# %% [markdown]
# To assess attribute dependency rules we should test that redundant attributes in different data sources have identical values.
#
# The sum of the races equals the the total population for the census tract.

# %%
#Derived attributes: aggregated valu must equal the total of the atmoic level values.
#Checking if the sum of the race categories equals the total population
food_access_2015['total_race_count'] = food_access_2015['TractWhite'] + food_access_2015['TractBlack'] + food_access_2015['TractAsian'] +  food_access_2015['TractNHOPI'] + food_access_2015['TractAIAN'] + food_access_2015['TractOMultir']

food_access_2015[['POP2010','total_race_count']]
# Out:
#        POP2010  total_race_count
# 66726     3818              3818
# 66727     2811              2811
# 66728     3152              3152
# 66729     6901              6901
# 66730     8186              8186
# ...        ...               ...
# 67309     6316              6316
# 67310     3073              3073
# 67311     5785              5785
# 67312     4452              4452
# 67313     6531              6531
#
# [588 rows x 2 columns]

# %% [markdown]
# # Conclusion

# %% [markdown]
# Overall, the quality of data is good in the the food access 2015 data set. There are no  missing values. The outputs in the columns are as expected for example they are a 0 or a 1 when they should be and the sum of the aggregrate race data matches the total population data. More assessment should be done when we combine the datasets to make sure the values are the same across sources for redundant columns.
#
# The facets dataset used the Low access to healthy food (1/2 mile). Since Utah has both rural and urban census tracts I think we should use the Low access tract at 1/2 mile for urban areas and 10 miles for rural areas column. That is the column I focused on in this assessment. There are other options to explore.

# %% [markdown]
# # Resources

# %% [markdown]
# Description of the columns: https://www.ers.usda.gov/data-products/food-access-research-atlas/documentation/#distance
#
# Download the data: https://www.ers.usda.gov/data-products/food-access-research-atlas/download-the-data/ in the zip files there is one spreadsheet that gives a brief explanation of the columns and another excel file with the actual data
#
# See the right hand side of both the links above for additional information about this data source.
